# %%
import requests
import pandas as pd
import plotly.graph_objects as go
import ipywidgets as widgets
import plotly.express as px
import numpy as np
import json

import requests
headers={'Authorization': 'Token d86787a69fdc41e2938783b9af11ec89051b4ac9'}
url='https://voyages3-api.crc.rice.edu/voyage/'
response=requests.get(url,headers=headers)

# %%
numeric_vars = ['voyage_slaves_numbers__imp_total_num_slaves_disembarked',
                'voyage_slaves_numbers__imp_total_num_slaves_embarked']

geo_vars = ['voyage_itinerary__imp_principal_place_of_slave_purchase__value',
           'voyage_itinerary__imp_principal_port_slave_dis__value']

date_vars = ['voyage_dates__arrival_at_second_place_landing_yyyy',
            'voyage_dates__date_departed_africa_yyyy',
            'voyage_dates__departure_last_place_of_landing_yyyy',
            'voyage_dates__first_dis_of_slaves_yyyy',
        'voyage_dates__imp_arrival_at_port_of_dis_yyyy',
        'voyage_dates__imp_departed_africa_yyyy',
        'voyage_dates__imp_voyage_began_yyyy',
        'voyage_dates__slave_purchase_began_yyyy',
        'voyage_dates__third_dis_of_slaves_yyyy',
        'voyage_dates__vessel_left_port_yyyy',
        'voyage_dates__voyage_began_yyyy',
        'voyage_dates__voyage_completed_yyyy']


r = requests.options('https://voyages3-api.crc.rice.edu/voyage/?hierarchical=False', headers=headers)
drop_dict = r.json()
drop_dict
# Out:
# {'id': {'type': "<class 'rest_framework.fields.IntegerField'>", 'label': 'ID'},
#  'voyage_itinerary__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_itinerary': {'type': 'table',
#   'label': 'Itinerary',
#   'model': 'voyage.models.VoyageItinerary'},
#  'voyage_itinerary__port_of_departure__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Port of departure (PORTDEP): ID'},
#  'voyage_itinerary__port_of_departure': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__port_of_departure__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__port_of_departure__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__port_of_departure__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__port_of_departure__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__port_of_departure__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__port_of_departure__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__port_of_departure__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__port_of_departure__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__port_of_departure__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__port_of_departure__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__port_of_departure__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__port_of_departure__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__port_of_departure__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__port_of_departure__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__port_of_departure__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__port_of_departure__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Port of departure (PORTDEP)'},
#  'voyage_itinerary__port_of_departure__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Port of departure (PORTDEP): Numeric code'},
#  'voyage_itinerary__port_of_departure__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Port of departure (PORTDEP): Longitude'},
#  'voyage_itinerary__port_of_departure__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Port of departure (PORTDEP): Latitude'},
#  'voyage_itinerary__port_of_departure__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Port of departure (PORTDEP): Show on main map'},
#  'voyage_itinerary__port_of_departure__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Port of departure (PORTDEP): Show on voyage map'},
#  'voyage_itinerary__int_first_port_emb__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended port of embarkation (EMBPORT): ID'},
#  'voyage_itinerary__int_first_port_emb': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__int_first_port_emb__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__int_first_port_emb__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_first_port_emb__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__int_first_port_emb__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_first_port_emb__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_first_port_emb__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_first_port_emb__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_first_port_emb__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__int_first_port_emb__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'First intended port of embarkation (EMBPORT)'},
#  'voyage_itinerary__int_first_port_emb__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended port of embarkation (EMBPORT): Numeric code'},
#  'voyage_itinerary__int_first_port_emb__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point'},
#  'voyage_itinerary__int_first_port_emb__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point'},
#  'voyage_itinerary__int_first_port_emb__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__int_first_port_emb__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on voyage map'},
#  'voyage_itinerary__int_second_port_emb__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended port of embarkation (EMBPORT): ID'},
#  'voyage_itinerary__int_second_port_emb': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__int_second_port_emb__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__int_second_port_emb__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_second_port_emb__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__int_second_port_emb__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_second_port_emb__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_second_port_emb__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_second_port_emb__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_second_port_emb__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__int_second_port_emb__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Second intended port of embarkation (EMBPORT2)'},
#  'voyage_itinerary__int_second_port_emb__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended port of embarkation (EMBPORT): Numeric code'},
#  'voyage_itinerary__int_second_port_emb__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended port of embarkation (EMBPORT): Longitude of point'},
#  'voyage_itinerary__int_second_port_emb__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended port of embarkation (EMBPORT): Latitude of point'},
#  'voyage_itinerary__int_second_port_emb__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended port of embarkation (EMBPORT): Show on main map'},
#  'voyage_itinerary__int_second_port_emb__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended port of embarkation (EMBPORT): Show on voyage map'},
#  'voyage_itinerary__int_first_region_purchase_slaves__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended region of purchase of slaves (EMBREG): ID'},
#  'voyage_itinerary__int_first_region_purchase_slaves': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_first_region_purchase_slaves__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'First intended region of purchase of slaves (EMBREG)'},
#  'voyage_itinerary__int_first_region_purchase_slaves__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended region of purchase of slaves (EMBREG): Longitude of point'},
#  'voyage_itinerary__int_first_region_purchase_slaves__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended region of purchase of slaves (EMBREG): Latitude of point'},
#  'voyage_itinerary__int_first_region_purchase_slaves__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended region of purchase of slaves (EMBREG): Numeric code'},
#  'voyage_itinerary__int_first_region_purchase_slaves__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended region of purchase of slaves (EMBREG): Show on map'},
#  'voyage_itinerary__int_first_region_purchase_slaves__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended region of purchase of slaves (EMBREG): Show on main map'},
#  'voyage_itinerary__int_second_region_purchase_slaves__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second intended region of purchase of slaves (EMBREG2): ID'},
#  'voyage_itinerary__int_second_region_purchase_slaves': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_second_region_purchase_slaves__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Second intended region of purchase of slaves (EMBREG2)'},
#  'voyage_itinerary__int_second_region_purchase_slaves__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second intended region of purchase of slaves (EMBREG2): Longitude of point'},
#  'voyage_itinerary__int_second_region_purchase_slaves__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second intended region of purchase of slaves (EMBREG2): Latitude of point'},
#  'voyage_itinerary__int_second_region_purchase_slaves__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second intended region of purchase of slaves (EMBREG2): Numeric code'},
#  'voyage_itinerary__int_second_region_purchase_slaves__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Second intended region of purchase of slaves (EMBREG2): Show on map'},
#  'voyage_itinerary__int_second_region_purchase_slaves__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Second intended region of purchase of slaves (EMBREG2): Show on main map'},
#  'voyage_itinerary__int_first_port_dis__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended port of disembarkation (ARRPORT): ID'},
#  'voyage_itinerary__int_first_port_dis': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__int_first_port_dis__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__int_first_port_dis__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_first_port_dis__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__int_first_port_dis__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_first_port_dis__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_first_port_dis__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_first_port_dis__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_first_port_dis__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__int_first_port_dis__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'First intended port of disembarkation (ARRPORT)'},
#  'voyage_itinerary__int_first_port_dis__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended port of disembarkation (ARRPORT): Numeric code'},
#  'voyage_itinerary__int_first_port_dis__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended port of disembarkation (ARRPORT): Longitude of point'},
#  'voyage_itinerary__int_first_port_dis__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended port of disembarkation (ARRPORT): Latitude of point'},
#  'voyage_itinerary__int_first_port_dis__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended port of disembarkation (ARRPORT): Show on main map'},
#  'voyage_itinerary__int_first_port_dis__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended port of disembarkation (ARRPORT): Show on voyage map'},
#  'voyage_itinerary__int_second_port_dis__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second intended port of disembarkation (ARRPORT2): ID'},
#  'voyage_itinerary__int_second_port_dis': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__int_second_port_dis__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__int_second_port_dis__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_second_port_dis__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__int_second_port_dis__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_second_port_dis__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_second_port_dis__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_second_port_dis__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_second_port_dis__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__int_second_port_dis__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Second intended port of disembarkation (ARRPORT2)'},
#  'voyage_itinerary__int_second_port_dis__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second intended port of disembarkation (ARRPORT2): Numeric code'},
#  'voyage_itinerary__int_second_port_dis__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second intended port of disembarkation (ARRPORT2): Longitude of point'},
#  'voyage_itinerary__int_second_port_dis__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second intended port of disembarkation (ARRPORT2): Latitude of point'},
#  'voyage_itinerary__int_second_port_dis__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Second intended port of disembarkation (ARRPORT2): Show on main map'},
#  'voyage_itinerary__int_second_port_dis__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Second intended port of disembarkation (ARRPORT2): Show on voyage map'},
#  'voyage_itinerary__int_first_region_slave_landing__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended region of slave landing (REGARR): ID'},
#  'voyage_itinerary__int_first_region_slave_landing': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_first_region_slave_landing__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'First intended region of slave landing (REGARR)'},
#  'voyage_itinerary__int_first_region_slave_landing__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended region of slave landing (REGARR): Longitude of point'},
#  'voyage_itinerary__int_first_region_slave_landing__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First intended region of slave landing (REGARR): Latitude of point'},
#  'voyage_itinerary__int_first_region_slave_landing__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First intended region of slave landing (REGARR): Numeric code'},
#  'voyage_itinerary__int_first_region_slave_landing__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended region of slave landing (REGARR): Show on map'},
#  'voyage_itinerary__int_first_region_slave_landing__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First intended region of slave landing (REGARR): Show on main map'},
#  'voyage_itinerary__imp_principal_region_slave_dis__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP): ID'},
#  'voyage_itinerary__imp_principal_region_slave_dis': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__imp_principal_region_slave_dis__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP)'},
#  'voyage_itinerary__imp_principal_region_slave_dis__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP): Longitude of point'},
#  'voyage_itinerary__imp_principal_region_slave_dis__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP): Latitude of point'},
#  'voyage_itinerary__imp_principal_region_slave_dis__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP): Numeric code'},
#  'voyage_itinerary__imp_principal_region_slave_dis__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP): Show on map'},
#  'voyage_itinerary__imp_principal_region_slave_dis__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP): Show on main map'},
#  'voyage_itinerary__int_second_place_region_slave_landing__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second intended region of slave landing (REGARR2): ID'},
#  'voyage_itinerary__int_second_place_region_slave_landing': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_second_place_region_slave_landing__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Second intended region of slave landing (REGARR2): Place'},
#  'voyage_itinerary__int_second_place_region_slave_landing__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second intended region of slave landing (REGARR2): Longitude of point'},
#  'voyage_itinerary__int_second_place_region_slave_landing__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second intended region of slave landing (REGARR2): Latitude of point'},
#  'voyage_itinerary__int_second_place_region_slave_landing__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second intended region of slave landing (REGARR2): Numeric code'},
#  'voyage_itinerary__int_second_place_region_slave_landing__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__int_second_place_region_slave_landing__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Second intended region of slave landing (REGARR2): Show on main map'},
#  'voyage_itinerary__first_place_slave_purchase__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First place of slave purchase (PLAC1TRA): ID'},
#  'voyage_itinerary__first_place_slave_purchase': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__first_place_slave_purchase__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__first_place_slave_purchase__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__first_place_slave_purchase__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__first_place_slave_purchase__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__first_place_slave_purchase__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__first_place_slave_purchase__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__first_place_slave_purchase__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__first_place_slave_purchase__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__first_place_slave_purchase__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__first_place_slave_purchase__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__first_place_slave_purchase__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__first_place_slave_purchase__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__first_place_slave_purchase__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__first_place_slave_purchase__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__first_place_slave_purchase__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__first_place_slave_purchase__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'First place of slave purchase (PLAC1TRA)'},
#  'voyage_itinerary__first_place_slave_purchase__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First place of slave purchase (PLAC1TRA): Numeric code'},
#  'voyage_itinerary__first_place_slave_purchase__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First place of slave purchase (PLAC1TRA): Longitude of point'},
#  'voyage_itinerary__first_place_slave_purchase__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First place of slave purchase (PLAC1TRA): Latitude of point'},
#  'voyage_itinerary__first_place_slave_purchase__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First place of slave purchase (PLAC1TRA): Show on main map'},
#  'voyage_itinerary__first_place_slave_purchase__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First place of slave purchase (PLAC1TRA): Show on voyage map'},
#  'voyage_itinerary__second_place_slave_purchase__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second place of slave purchase (PLAC2TRA): ID'},
#  'voyage_itinerary__second_place_slave_purchase': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__second_place_slave_purchase__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__second_place_slave_purchase__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__second_place_slave_purchase__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__second_place_slave_purchase__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__second_place_slave_purchase__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__second_place_slave_purchase__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__second_place_slave_purchase__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__second_place_slave_purchase__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__second_place_slave_purchase__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__second_place_slave_purchase__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__second_place_slave_purchase__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__second_place_slave_purchase__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__second_place_slave_purchase__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__second_place_slave_purchase__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__second_place_slave_purchase__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__second_place_slave_purchase__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Second place of slave purchase (PLAC2TRA)'},
#  'voyage_itinerary__second_place_slave_purchase__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second place of slave purchase (PLAC2TRA): Numeric code'},
#  'voyage_itinerary__second_place_slave_purchase__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second place of slave purchase (PLAC2TRA): Longitude of point'},
#  'voyage_itinerary__second_place_slave_purchase__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second place of slave purchase (PLAC2TRA): Latitude of point'},
#  'voyage_itinerary__second_place_slave_purchase__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Second place of slave purchase (PLAC2TRA): Show on main map'},
#  'voyage_itinerary__second_place_slave_purchase__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Second place of slave purchase (PLAC2TRA): Show on voyage map'},
#  'voyage_itinerary__third_place_slave_purchase__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Third place of slave purchase (PLAC3TRA): ID'},
#  'voyage_itinerary__third_place_slave_purchase': {'type': 'table',
#   'label': 'Place (Port or Location)',
#   'model': 'voyage.models.Place'},
#  'voyage_itinerary__third_place_slave_purchase__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Region ID'},
#  'voyage_itinerary__third_place_slave_purchase__region': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__third_place_slave_purchase__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__third_place_slave_purchase__region__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__third_place_slave_purchase__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__third_place_slave_purchase__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__third_place_slave_purchase__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__third_place_slave_purchase__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__third_place_slave_purchase__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__third_place_slave_purchase__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)'},
#  'voyage_itinerary__third_place_slave_purchase__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__third_place_slave_purchase__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__third_place_slave_purchase__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__third_place_slave_purchase__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__third_place_slave_purchase__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map'},
#  'voyage_itinerary__third_place_slave_purchase__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Third place of slave purchase (PLAC3TRA)'},
#  'voyage_itinerary__third_place_slave_purchase__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Third place of slave purchase (PLAC3TRA): Numeric code'},
#  'voyage_itinerary__third_place_slave_purchase__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Third place of slave purchase (PLAC3TRA): Longitude of point'},
#  'voyage_itinerary__third_place_slave_purchase__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Third place of slave purchase (PLAC3TRA): Latitude of point'},
#  'voyage_itinerary__third_place_slave_purchase__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Third place of slave purchase (PLAC3TRA): Show on main map'},
#  'voyage_itinerary__third_place_slave_purchase__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Third place of slave purchase (PLAC3TRA): Show on voyage map'},
#  'voyage_itinerary__first_region_slave_emb__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First region of embarkation of slaves (REGEM1): ID'},
#  'voyage_itinerary__first_region_slave_emb': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__first_region_slave_emb__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__first_region_slave_emb__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__first_region_slave_emb__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__first_region_slave_emb__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__first_region_slave_emb__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__first_region_slave_emb__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__first_region_slave_emb__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__first_region_slave_emb__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'First region of embarkation of slaves (REGEM1)'},
#  'voyage_itinerary__first_region_slave_emb__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First region of embarkation of slaves (REGEM1): Longitude of point'},
#  'voyage_itinerary__first_region_slave_emb__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'First region of embarkation of slaves (REGEM1): Latitude of point'},
#  'voyage_itinerary__first_region_slave_emb__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'First region of embarkation of slaves (REGEM1): Numeric code'},
#  'voyage_itinerary__first_region_slave_emb__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First region of embarkation of slaves (REGEM1): Show on map'},
#  'voyage_itinerary__first_region_slave_emb__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'First region of embarkation of slaves (REGEM1): Show on main map'},
#  'voyage_itinerary__second_region_slave_emb__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Second region of embarkation of slaves (REGEM2): ID'},
#  'voyage_itinerary__second_region_slave_emb': {'type': 'table',
#   'label': 'Region',
#   'model': 'voyage.models.Region'},
#  'voyage_itinerary__second_region_slave_emb__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Broad region (area) ID'},
#  'voyage_itinerary__second_region_slave_emb__broad_region': {'type': 'table',
#   'label': 'Broad region (area)',
#   'model': 'voyage.models.BroadRegion'},
#  'voyage_itinerary__second_region_slave_emb__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name'},
#  'voyage_itinerary__second_region_slave_emb__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude'},
#  'voyage_itinerary__second_region_slave_emb__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude'},
#  'voyage_itinerary__second_region_slave_emb__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code'},
#  'voyage_itinerary__second_region_slave_emb__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map'},
#  'voyage_itinerary__second_region_slave_emb__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Second region of embarkation of slaves (REGEM2)'},
#  'voyage_itinerary__second_region_slave_emb__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second region of embarkation of slaves (REGEM2): Longitude of point'},
#  'voyage_itinerary__second_region_slave_emb__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Second region of embarkation of slaves (REGEM2): Latitude of point'},
#  'voyage_itinerary__second_region_slave_emb__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
# ...
#   'label': 'Number of infants (INFANT5) embarked at third port of purchase'},
#  'voyage_slaves_numbers__num_males_embark_third_port_purchase': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of males (age unspecified) (MALE5) embarked at third port of purchase'},
#  'voyage_slaves_numbers__num_females_embark_third_port_purchase': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of females (age unspecified) (FEMALE5) embarked at third port of purchase'},
#  'voyage_slaves_numbers__num_men_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of men (MEN6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_women_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of women (WOMEN6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_boy_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of boys (BOY6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_girl_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of girls (GIRL6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_adult_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of adults (gender unspecified) (ADULT6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_child_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of children (gender unspecified) (CHILD6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_infant_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of infants (INFANT6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_males_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of males (age unspecified) (MALE6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__num_females_disembark_second_landing': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of females (age unspecified) (FEMALE6) disembarked at second place of landing'},
#  'voyage_slaves_numbers__imp_num_adult_embarked': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of adults embarked (ADLT1IMP)'},
#  'voyage_slaves_numbers__imp_num_children_embarked': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of adults embarked (CHIL1IMP)'},
#  'voyage_slaves_numbers__imp_num_male_embarked': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of males embarked (MALE1IMP)'},
#  'voyage_slaves_numbers__imp_num_female_embarked': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of females embarked (FEML1IMP)'},
#  'voyage_slaves_numbers__total_slaves_embarked_age_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves embarked with age identified (SLAVEMA1)'},
#  'voyage_slaves_numbers__total_slaves_embarked_gender_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves embarked with gender identified (SLAVEMX1)'},
#  'voyage_slaves_numbers__imp_adult_death_middle_passage': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of adults who died on Middle Passage (ADLT2IMP)'},
#  'voyage_slaves_numbers__imp_child_death_middle_passage': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of children who died on Middle Passage (CHIL2IMP)'},
#  'voyage_slaves_numbers__imp_male_death_middle_passage': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of males who died on Middle Passage (MALE2IMP)'},
#  'voyage_slaves_numbers__imp_female_death_middle_passage': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of females who died on Middle Passage (FEML2IMP)'},
#  'voyage_slaves_numbers__imp_num_adult_landed': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of adults landed (ADLT3IMP)'},
#  'voyage_slaves_numbers__imp_num_child_landed': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of children landed (CHIL3IMP)'},
#  'voyage_slaves_numbers__imp_num_male_landed': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of males landed (MALE3IMP)'},
#  'voyage_slaves_numbers__imp_num_female_landed': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of females landed (FEML3IMP)'},
#  'voyage_slaves_numbers__total_slaves_landed_age_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age among landed slaves (SLAVEMA3)'},
#  'voyage_slaves_numbers__total_slaves_landed_gender_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by gender among landed slaves (SLAVEMX3)'},
#  'voyage_slaves_numbers__total_slaves_dept_or_arr_age_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age at departure or arrival (SLAVEMA7)'},
#  'voyage_slaves_numbers__total_slaves_dept_or_arr_gender_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by gender at departure or arrival(SLAVEMX7)'},
#  'voyage_slaves_numbers__imp_slaves_embarked_for_mortality': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of slaves embarked for mortality calculation (TSLMTIMP)'},
#  'voyage_slaves_numbers__imp_num_men_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of men (MEN7)'},
#  'voyage_slaves_numbers__imp_num_women_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of women (WOMEN7) '},
#  'voyage_slaves_numbers__imp_num_boy_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of boys (BOY7)'},
#  'voyage_slaves_numbers__imp_num_girl_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of girls (GIRL7)'},
#  'voyage_slaves_numbers__imp_num_adult_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of adults (gender unspecified) (ADULT7)'},
#  'voyage_slaves_numbers__imp_num_child_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of children (gender unspecified) (CHILD7)'},
#  'voyage_slaves_numbers__imp_num_males_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of males (age unspecified) (MALE7)'},
#  'voyage_slaves_numbers__imp_num_females_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of females (age unspecified) (FEMALE7) '},
#  'voyage_slaves_numbers__total_slaves_embarked_age_gender_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves embarked wi th age and gender identified (SLAVMAX1)'},
#  'voyage_slaves_numbers__total_slaves_by_age_gender_identified_among_landed': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age and gender among landed (SLAVMAX3)'},
#  'voyage_slaves_numbers__total_slaves_by_age_gender_identified_departure_or_arrival': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age and gender at departure or arrival (SLAVMAX7)'},
#  'voyage_slaves_numbers__percentage_boys_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of boys among embarked slaves (BOYRAT1)'},
#  'voyage_slaves_numbers__child_ratio_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Child ratio among embarked slaves (CHILRAT1)'},
#  'voyage_slaves_numbers__percentage_girls_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of girls among embarked slaves (GIRLRAT1)'},
#  'voyage_slaves_numbers__male_ratio_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Male ratio among embarked slaves (MALRAT1)'},
#  'voyage_slaves_numbers__percentage_men_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of men among embarked slaves (MENRAT1)'},
#  'voyage_slaves_numbers__percentage_women_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of women among embarked slaves (WOMRAT1)'},
#  'voyage_slaves_numbers__percentage_boys_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of boys among landed slaves (BOYRAT3)'},
#  'voyage_slaves_numbers__child_ratio_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Child ratio among landed slaves (CHILRAT3)'},
#  'voyage_slaves_numbers__percentage_girls_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of girls among landed slaves (GIRLRAT3)'},
#  'voyage_slaves_numbers__male_ratio_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Male ratio among landed slaves (MALRAT3)'},
#  'voyage_slaves_numbers__percentage_men_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of men among landed slaves (MENRAT3)'},
#  'voyage_slaves_numbers__percentage_women_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of women among landed slaves (WOMRAT3)'},
#  'voyage_slaves_numbers__percentage_men': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage men on voyage (MENRAT7)'},
#  'voyage_slaves_numbers__percentage_women': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage women on voyage (WOMRAT7)'},
#  'voyage_slaves_numbers__percentage_boy': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage boy on voyage (BOYRAT7)'},
#  'voyage_slaves_numbers__percentage_girl': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage girl on voyage (GIRLRAT7)'},
#  'voyage_slaves_numbers__percentage_male': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage male on voyage (MALRAT7)'},
#  'voyage_slaves_numbers__percentage_child': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage children on voyage (CHILRAT7)'},
#  'voyage_slaves_numbers__percentage_adult': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage adult on voyage'},
#  'voyage_slaves_numbers__percentage_female': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage female on voyage'},
#  'voyage_slaves_numbers__imp_mortality_ratio': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Imputed mortality ratio (VYMRTRAT)'},
#  'voyage_slaves_numbers__voyage': {'type': "<class 'rest_framework.relations.PrimaryKeyRelatedField'>",
#   'label': 'Voyage'},
#  'voyage_outcome__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_outcome': {'type': 'table',
#   'label': 'Outcome',
#   'model': 'voyage.models.VoyageOutcome'},
#  'voyage_outcome__outcome_owner__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_outcome__outcome_owner': {'type': 'table',
#   'label': 'Owner Outcome',
#   'model': 'voyage.models.OwnerOutcome'},
#  'voyage_outcome__outcome_owner__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Owner Outcome'},
#  'voyage_outcome__outcome_owner__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome'},
#  'voyage_outcome__outcome_slaves__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_outcome__outcome_slaves': {'type': 'table',
#   'label': 'Captives Outcome',
#   'model': 'voyage.models.SlavesOutcome'},
#  'voyage_outcome__outcome_slaves__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Slaves Outcome'},
#  'voyage_outcome__outcome_slaves__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome'},
#  'voyage_outcome__particular_outcome__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_outcome__particular_outcome': {'type': 'table',
#   'label': 'Fate (particular outcome of voyage)',
#   'model': 'voyage.models.ParticularOutcome'},
#  'voyage_outcome__particular_outcome__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Particular Outcome'},
#  'voyage_outcome__particular_outcome__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome'},
#  'voyage_outcome__resistance__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_outcome__resistance': {'type': 'table',
#   'label': 'Resistance',
#   'model': 'voyage.models.Resistance'},
#  'voyage_outcome__resistance__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Resistance'},
#  'voyage_outcome__resistance__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of resistance'},
#  'voyage_outcome__vessel_captured_outcome__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_outcome__vessel_captured_outcome': {'type': 'table',
#   'label': 'Vessel Captured Outcome',
#   'model': 'voyage.models.VesselCapturedOutcome'},
#  'voyage_outcome__vessel_captured_outcome__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Vessel Captured Outcome'},
#  'voyage_outcome__vessel_captured_outcome__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome'},
#  'voyage_outcome__voyage': {'type': "<class 'rest_framework.relations.PrimaryKeyRelatedField'>",
#   'label': 'Voyage'},
#  'voyage_sourceconnection__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_sourceconnection': {'type': 'table',
#   'label': 'voyage sources connection',
#   'model': 'voyage.models.VoyageSourcesConnection'},
#  'voyage_sourceconnection__source__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID'},
#  'voyage_sourceconnection__source': {'type': 'table',
#   'label': 'Source',
#   'model': 'voyage.models.VoyageSources'},
#  'voyage_sourceconnection__source__short_ref': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Short reference'},
#  'voyage_sourceconnection__source__full_ref': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Full reference'},
#  'voyage_sourceconnection__source__source_type': {'type': "<class 'rest_framework.relations.PrimaryKeyRelatedField'>",
#   'label': 'Source Type'},
#  'voyage_sourceconnection__text_ref': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Text reference(citation)'},
#  'voyage_id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Voyage ID'},
#  'voyage_in_cd_rom': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Voyage in 1999 CD-ROM?'},
#  'last_update': {'type': "<class 'rest_framework.fields.DateTimeField'>",
#   'label': 'Last update'},
#  'dataset': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Dataset'},
#  'voyage_captainconnection__captain': {'type': 'table',
#   'label': 'Captain',
#   'model': 'voyage.models.VoyageCaptain'},
#  'voyage_shipownerconnection__owner': {'type': 'table',
#   'label': 'Ship Owner',
#   'model': 'voyage.models.VoyageShipOwner'}}

# %%
geo_drop = [drop_dict[i]['label'] for i in geo_vars]

emb3 = widgets.Dropdown(
    options=geo_drop,
    description="Parameter",
    disabled=False,
)
emb3
# Out:
# Dropdown(description='Parameter', options=('Imputed principal place of slave purchase (MJBYPTIMP): Numeric cod…

# %%
numeric_drop = [drop_dict[i]['label'] for i in numeric_vars]

"""
construct the url also from the values thrown from the dropdown
geo_vars : similar : array with two items, each of those items represent embarked disembarked
dates_vars : similar : ^
port of emb: lat, lon, name, num slaves emb
same for disemb
"""

"""
mutate df to include three new columns 
"""

"""
drop down says what the dates_vars the user wants: NUMERIC_DATES_VARS
then have a slider which chooses the dates as well
http://152.70.193.224:8000/voyage/aggregations?aggregate_fields=voyage_dates__imp_arrival_at_port_of_dis_yyyy
"""

emb = widgets.Dropdown(
    options=numeric_drop,
    description="Numeric Vars",
    disabled=False,
)

emb
# Out:
# Dropdown(description='Numeric Vars', options=('Total slaves disembarked imputed * (SLAMIMP)', 'Total slaves em…

# %%
date_drop = [drop_dict[i]['label'] for i in date_vars]
date_drop

emb1 = widgets.Dropdown(
    options=date_drop,
    description="Dates Vars",
    disabled=False,
)
emb1
# Out:
# Dropdown(description='Dates Vars', options=('Year of arrival at second place of landing (DATARR37,36,38)', 'Ye…

# %%
emb2 = widgets.IntRangeSlider(
    value=[1810, 1817],
    min=1810,
    max=1830,
    step=1,
    description='Date Slider',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d',
)
emb2
# Out:
# IntRangeSlider(value=(1810, 1817), continuous_update=False, description='Date Slider', max=1830, min=1810)

# %%
emb2.value[1]
# Out:
# 1817

# %%
url = 'https://voyages3-api.crc.rice.edu/voyage/dataframes?selected_fields=' + date_vars[date_drop.index(emb1.value)] + ',voyage_itinerary__imp_principal_place_of_slave_purchase__latitude,voyage_itinerary__imp_principal_place_of_slave_purchase__longitude,' + geo_vars[geo_drop.index(emb3.value)] + ',' + numeric_vars[numeric_drop.index(emb.value)] + '&' + date_vars[date_drop.index(emb1.value)] + '=' + str(emb2.value[0]) + ',' + str(emb2.value[1])
URL2 = "http://152.70.193.224:8000/voyage/aggregations?aggregate_fields="
r = requests.get(url, headers=headers)
j = r.text
df = pd.read_json(j)
df = df.dropna()
df = df.sort_values(by=[date_vars[date_drop.index(emb1.value)]])

df2 = df.groupby(['voyage_itinerary__imp_principal_place_of_slave_purchase__longitude', 
                  'voyage_itinerary__imp_principal_place_of_slave_purchase__latitude', 
                  geo_vars[geo_drop.index(emb3.value)], 
                  date_vars[date_drop.index(emb1.value)]], as_index=False).sum()

df2 = df2.rename({'voyage_itinerary__imp_principal_place_of_slave_purchase__longitude': 'Longitude',
                  'voyage_itinerary__imp_principal_place_of_slave_purchase__latitude': 'Latitude', 
                  geo_vars[geo_drop.index(emb3.value)]: emb3.value,
                  numeric_vars[numeric_drop.index(emb.value)] : emb.value,
                  date_vars[date_drop.index(emb1.value)]: emb1.value, 
                 }, axis=1)

df2 = df2.assign(normalized_sizes = np.log(df2[emb.value]))

fig = px.scatter_geo(df2, lon = 'Longitude',
                     lat = 'Latitude',
                     hover_name = emb3.value,
                     animation_frame = emb1.value,
                     size = 'normalized_sizes',
                     hover_data = [emb.value])
fig.show()
# Out:
# <div>                            <div id="3bdd6679-9d39-4138-8de5-84ae69c8a20c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bdd6679-9d39-4138-8de5-84ae69c8a20c")) {                    Plotly.newPlot(                        "3bdd6679-9d39-4138-8de5-84ae69c8a20c",                        [{"customdata":[[138]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Year of third disembarkation of slaves (DATARR40,39,41)=1816<br>normalized_sizes=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<br>Total slaves disembarked imputed * (SLAMIMP)=%{customdata[0]}<extra></extra>","hovertext":[60999.0],"lat":[0.054033],"legendgroup":"","lon":[9.343897],"marker":{"color":"#636efa","size":[4.927253685157205],"sizemode":"area","sizeref":0.014616096937644311,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidt ...

# %%
fig = px.bar(df2, x=emb1.value,
             y=emb.value, color=emb3.value
             )
fig.update_xaxes(dtick=1)
fig.show()
# Out:
# <div>                            <div id="1dcc2b26-eb37-4000-bc6d-2e2227f52480" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dcc2b26-eb37-4000-bc6d-2e2227f52480")) {                    Plotly.newPlot(                        "1dcc2b26-eb37-4000-bc6d-2e2227f52480",                        [{"alignmentgroup":"True","hovertemplate":"Year of third disembarkation of slaves (DATARR40,39,41)=%{x}<br>Total slaves disembarked imputed * (SLAMIMP)=%{y}<br>Imputed principal place of slave purchase (MJBYPTIMP): Numeric code=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[60999,60999,60999],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1816,1817,1818],"xaxis":"x","y":[138,170,346],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoo ...

# %%
"""
Issues to discuss:
1. have to manually create generic labels
2. Had to use groupby as NaN values caused issues with graph creation
3. Unclear about port of emb and disemb and their relationship to the above data
"""

# %%
print("+++FETCHING GEO+++")
r=requests.get("https://voyages3-api.crc.rice.edu/voyage/geo?hierarchical=False&auto=True", headers=headers)
flatgeo=json.loads(r.text)
print("+++GEO FETCHED+++")

type_prefixes={'place':'','region':'region__','broad_region':'region__broad_region__'}
geo_codes={}
default_geocode=0

geo_codes[default_geocode]={
    "type": "Feature",
    "geometry": {
        "type": "Point",
        "coordinates": [0,0]
    },
    "properties": {
        "name":"Unknown",
        "id":default_geocode
    }
}

for i in flatgeo:
    for tp in type_prefixes:
        prefix=type_prefixes[tp]
        geocode=i[prefix+'value']
        if geocode is None:
            geocode=default_geocode

        longitude=i[prefix+'longitude']
        latitude=i[prefix+'latitude']
        if latitude is None:
            latitude=0
        if longitude is None:
            longitude=0
        latitude=float(latitude)
        longitude=float(longitude)

        d={
            "type": "Feature",
            "geometry": {
                "type": "Point",
                "coordinates": [longitude,latitude]
            },
            "properties": {
                "class":tp,
                tp:i[prefix+tp],
                "name":i[prefix+tp],
                "id":i[prefix+'value']
            }
        }
        for k in [j for j in i if j.startswith(prefix+"show_on")]:
            d['properties'][k]=i[k]
        geo_codes[geocode]=d
geo_codes
# Out:
# +++FETCHING GEO+++
# +++GEO FETCHED+++
# {0: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0, 0]},
#   'properties': {'name': 'Unknown', 'id': 0}},
#  10101: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Alicante',
#    'name': 'Alicante',
#    'id': 10101,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10100: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-6.862857, 37.200782]},
#   'properties': {'class': 'region',
#    'region': 'Spain',
#    'name': 'Spain',
#    'id': 10100,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  10000: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.561913, 37.213255]},
#   'properties': {'class': 'broad_region',
#    'broad_region': 'Europe',
#    'name': 'Europe',
#    'id': 10000,
#    'region__broad_region__show_on_map': True}},
#  10102: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.18333, 41.38333]},
#   'properties': {'class': 'place',
#    'place': 'Barcelona',
#    'name': 'Barcelona',
#    'id': 10102,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10103: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.96667, 43.25]},
#   'properties': {'class': 'place',
#    'place': 'Bilbao',
#    'name': 'Bilbao',
#    'id': 10103,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10104: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-6.29944, 36.53361]},
#   'properties': {'class': 'place',
#    'place': 'Cadiz',
#    'name': 'Cadiz',
#    'id': 10104,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10105: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Figuera',
#    'name': 'Figuera',
#    'id': 10105,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10106: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.35, 36.13333]},
#   'properties': {'class': 'place',
#    'place': 'Gibraltar',
#    'name': 'Gibraltar',
#    'id': 10106,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10107: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.38333, 43.36667]},
#   'properties': {'class': 'place',
#    'place': 'La Coruña',
#    'name': 'La Coruña',
#    'id': 10107,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10110: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.80444, 43.46472]},
#   'properties': {'class': 'place',
#    'place': 'Santander',
#    'name': 'Santander',
#    'id': 10110,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10111: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.98694, 37.37722]},
#   'properties': {'class': 'place',
#    'place': 'Seville',
#    'name': 'Seville',
#    'id': 10111,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10112: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-6.35, 36.78333]},
#   'properties': {'class': 'place',
#    'place': 'San Lucar',
#    'name': 'San Lucar',
#    'id': 10112,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10113: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.72, 42.23333]},
#   'properties': {'class': 'place',
#    'place': 'Vigo',
#    'name': 'Vigo',
#    'id': 10113,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10115: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-6.258837, 36.639328]},
#   'properties': {'class': 'place',
#    'place': 'Puerto Santa Maria',
#    'name': 'Puerto Santa Maria',
#    'id': 10115,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10199: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-6.29944, 36.53361]},
#   'properties': {'class': 'place',
#    'place': 'Spain, port unspecified',
#    'name': 'Spain, port unspecified',
#    'id': 10199,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10202: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.66667, 37.1]},
#   'properties': {'class': 'place',
#    'place': 'Lagos',
#    'name': 'Lagos',
#    'id': 10202,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10200: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.838545, 40.046745]},
#   'properties': {'class': 'region',
#    'region': 'Portugal',
#    'name': 'Portugal',
#    'id': 10200,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  10203: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-9.13333, 38.71667]},
#   'properties': {'class': 'place',
#    'place': 'Lisbon',
#    'name': 'Lisbon',
#    'id': 10203,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10204: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.61667, 41.15]},
#   'properties': {'class': 'place',
#    'place': 'Oporto',
#    'name': 'Oporto',
#    'id': 10204,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10205: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-28.7, 38.56667]},
#   'properties': {'class': 'place',
#    'place': 'Ilho do Fayal',
#    'name': 'Ilho do Fayal',
#    'id': 10205,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10206: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.89307, 38.5245]},
#   'properties': {'class': 'place',
#    'place': 'Setubal',
#    'name': 'Setubal',
#    'id': 10206,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10299: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-9.13333, 38.71667]},
#   'properties': {'class': 'place',
#    'place': 'Portugal, port unspecified',
#    'name': 'Portugal, port unspecified',
#    'id': 10299,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10399: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.11667, 51.5]},
#   'properties': {'class': 'place',
#    'place': 'Great Britain, port unspecified',
#    'name': 'Great Britain, port unspecified',
#    'id': 10399,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10300: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-61.495298, 16.264142]},
#   'properties': {'class': 'region',
#    'region': 'Great Britain',
#    'name': 'Great Britain',
#    'id': 10300,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  10401: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Barmouth',
#    'name': 'Barmouth',
#    'id': 10401,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10400: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'region',
#    'region': 'England',
#    'name': 'England',
#    'id': 10400,
#    'region__show_on_map': False,
#    'region__show_on_main_map': True}},
#  10402: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Bideford',
#    'name': 'Bideford',
#    'id': 10402,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10403: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Birkenhead',
#    'name': 'Birkenhead',
#    'id': 10403,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10404: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.58333, 51.45]},
#   'properties': {'class': 'place',
#    'place': 'Bristol',
#    'name': 'Bristol',
#    'id': 10404,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10405: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Brixham',
#    'name': 'Brixham',
#    'id': 10405,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10406: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.45, 51.36667]},
#   'properties': {'class': 'place',
#    'place': 'Broadstairs',
#    'name': 'Broadstairs',
#    'id': 10406,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10407: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Cawsand',
#    'name': 'Cawsand',
#    'id': 10407,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10408: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Chepstow',
#    'name': 'Chepstow',
#    'id': 10408,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10409: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.91667, 53.2]},
#   'properties': {'class': 'place',
#    'place': 'Chester',
#    'name': 'Chester',
#    'id': 10409,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10410: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.9, 51.88333]},
#   'properties': {'class': 'place',
#    'place': 'Colchester',
#    'name': 'Colchester',
#    'id': 10410,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10411: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.3, 50.76667]},
#   'properties': {'class': 'place',
#    'place': 'Cowes',
#    'name': 'Cowes',
#    'id': 10411,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10412: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.58333, 50.35]},
#   'properties': {'class': 'place',
#    'place': 'Dartmouth',
#    'name': 'Dartmouth',
#    'id': 10412,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10413: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Deptford',
#    'name': 'Deptford',
#    'id': 10413,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10414: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.3, 51.13333]},
#   'properties': {'class': 'place',
#    'place': 'Dover',
#    'name': 'Dover',
#    'id': 10414,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10415: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.53333, 50.7]},
#   'properties': {'class': 'place',
#    'place': 'Exeter',
#    'name': 'Exeter',
#    'id': 10415,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10416: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.18333, 51.08333]},
#   'properties': {'class': 'place',
#    'place': 'Folkstone',
#    'name': 'Folkstone',
#    'id': 10416,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10417: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Frodsham',
#    'name': 'Frodsham',
#    'id': 10417,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10418: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Gainsborough',
#    'name': 'Gainsborough',
#    'id': 10418,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10419: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Greenwich',
#    'name': 'Greenwich',
#    'id': 10419,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10420: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.53333, 49.45]},
#   'properties': {'class': 'place',
#    'place': 'Guernsey',
#    'name': 'Guernsey',
#    'id': 10420,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10421: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Harwich',
#    'name': 'Harwich',
#    'id': 10421,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10422: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.33333, 53.71667]},
#   'properties': {'class': 'place',
#    'place': 'Hull',
#    'name': 'Hull',
#    'id': 10422,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10423: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Ilfracombe',
#    'name': 'Ilfracombe',
#    'id': 10423,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10424: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.16667, 52.08333]},
#   'properties': {'class': 'place',
#    'place': 'Ipswich',
#    'name': 'Ipswich',
#    'id': 10424,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10425: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Isle of Man',
#    'name': 'Isle of Man',
#    'id': 10425,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10426: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Isle of Wight',
#    'name': 'Isle of Wight',
#    'id': 10426,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10427: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Jersey',
#    'name': 'Jersey',
#    'id': 10427,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10428: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.75, 54.31667]},
#   'properties': {'class': 'place',
#    'place': 'Kendal',
#    'name': 'Kendal',
#    'id': 10428,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10429: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': "King's Lynn",
#    'name': "King's Lynn",
#    'id': 10429,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10430: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.83333, 54.06667]},
#   'properties': {'class': 'place',
#    'place': 'Lancaster',
#    'name': 'Lancaster',
#    'id': 10430,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10431: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Lindale',
#    'name': 'Lindale',
#    'id': 10431,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10432: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.0, 53.41667]},
#   'properties': {'class': 'place',
#    'place': 'Liverpool',
#    'name': 'Liverpool',
#    'id': 10432,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10433: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.11667, 51.5]},
#   'properties': {'class': 'place',
#    'place': 'London',
#    'name': 'London',
#    'id': 10433,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10434: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.93333, 50.73333]},
#   'properties': {'class': 'place',
#    'place': 'Lyme',
#    'name': 'Lyme',
#    'id': 10434,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10436: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Maryport',
#    'name': 'Maryport',
#    'id': 10436,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10437: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.03333, 51.71667]},
#   'properties': {'class': 'place',
#    'place': 'Milford Haven',
#    'name': 'Milford Haven',
#    'id': 10437,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10438: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.23333, 50.83333]},
#   'properties': {'class': 'place',
#    'place': 'New Shoreham',
#    'name': 'New Shoreham',
#    'id': 10438,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10439: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.61944, 54.98806]},
#   'properties': {'class': 'place',
#    'place': 'Newcastle upon Tyne',
#    'name': 'Newcastle upon Tyne',
#    'id': 10439,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10440: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Newnham',
#    'name': 'Newnham',
#    'id': 10440,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10441: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'North Shields',
#    'name': 'North Shields',
#    'id': 10441,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10442: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Northam',
#    'name': 'Northam',
#    'id': 10442,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10443: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Norwich',
#    'name': 'Norwich',
#    'id': 10443,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10444: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.93333, 50.53333]},
#   'properties': {'class': 'place',
#    'place': 'Padstowe',
#    'name': 'Padstowe',
#    'id': 10444,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10445: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-6.1, 54.71667]},
#   'properties': {'class': 'place',
#    'place': 'Parkgate',
#    'name': 'Parkgate',
#    'id': 10445,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10446: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Piel of Foulney',
#    'name': 'Piel of Foulney',
#    'id': 10446,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10447: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.13861, 50.39639]},
#   'properties': {'class': 'place',
#    'place': 'Plymouth',
#    'name': 'Plymouth',
#    'id': 10447,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10448: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.0, 50.71667]},
#   'properties': {'class': 'place',
#    'place': 'Poole',
#    'name': 'Poole',
#    'id': 10448,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10449: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Portsery',
#    'name': 'Portsery',
#    'id': 10449,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10450: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.08333, 50.76667]},
#   'properties': {'class': 'place',
#    'place': 'Portsmouth',
#    'name': 'Portsmouth',
#    'id': 10450,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10451: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.98333, 53.83333]},
#   'properties': {'class': 'place',
#    'place': 'Poulton',
#    'name': 'Poulton',
#    'id': 10451,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10452: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.72, 53.76667]},
#   'properties': {'class': 'place',
#    'place': 'Preston',
#    'name': 'Preston',
#    'id': 10452,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10453: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Ramsgate',
#    'name': 'Ramsgate',
#    'id': 10453,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10454: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Ravenglass',
#    'name': 'Ravenglass',
#    'id': 10454,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10455: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.40642, 51.42687]},
#   'properties': {'class': 'place',
#    'place': 'River Thames',
#    'name': 'River Thames',
#    'id': 10455,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10456: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Rochester',
#    'name': 'Rochester',
#    'id': 10456,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10457: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Rotherhithe',
#    'name': 'Rotherhithe',
#    'id': 10457,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10458: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Rye',
#    'name': 'Rye',
#    'id': 10458,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10459: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Scarborough',
#    'name': 'Scarborough',
#    'id': 10459,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10460: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Sheerness',
#    'name': 'Sheerness',
#    'id': 10460,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10461: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Shields',
#    'name': 'Shields',
#    'id': 10461,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10462: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.23333, 50.83333]},
#   'properties': {'class': 'place',
#    'place': 'Shoreham',
#    'name': 'Shoreham',
#    'id': 10462,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10463: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Sidmouth',
#    'name': 'Sidmouth',
#    'id': 10463,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10464: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.4, 50.9]},
#   'properties': {'class': 'place',
#    'place': 'Southampton',
#    'name': 'Southampton',
#    'id': 10464,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10466: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.42, 54.58333]},
#   'properties': {'class': 'place',
#    'place': 'Stockton',
#    'name': 'Stockton',
#    'id': 10466,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10467: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Stockwithe',
#    'name': 'Stockwithe',
#    'id': 10467,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10468: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Sunderland',
#    'name': 'Sunderland',
#    'id': 10468,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10469: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Teignmouth',
#    'name': 'Teignmouth',
#    'id': 10469,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10470: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.45, 50.68333]},
#   'properties': {'class': 'place',
#    'place': 'Topsham',
#    'name': 'Topsham',
#    'id': 10470,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10471: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Torbay',
#    'name': 'Torbay',
#    'id': 10471,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10472: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.68431, 52.35734]},
#   'properties': {'class': 'place',
#    'place': 'Wales',
#    'name': 'Wales',
#    'id': 10472,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10473: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.63056, 54.48667]},
#   'properties': {'class': 'place',
#    'place': 'Whitby',
#    'name': 'Whitby',
#    'id': 10473,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10474: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.6, 54.55]},
#   'properties': {'class': 'place',
#    'place': 'Whitehaven',
#    'name': 'Whitehaven',
#    'id': 10474,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10476: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Workington',
#    'name': 'Workington',
#    'id': 10476,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10477: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.5, 50.7]},
#   'properties': {'class': 'place',
#    'place': 'Yarmouth',
#    'name': 'Yarmouth',
#    'id': 10477,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10478: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Youghal',
#    'name': 'Youghal',
#    'id': 10478,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10479: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Conway',
#    'name': 'Conway',
#    'id': 10479,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10480: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.07106, 50.15599]},
#   'properties': {'class': 'place',
#    'place': 'Falmouth (Eng.)',
#    'name': 'Falmouth (Eng.)',
#    'id': 10480,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10481: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.035233, 51.51324]},
#   'properties': {'class': 'place',
#    'place': 'Lymehouse (a) Limehouse',
#    'name': 'Lymehouse (a) Limehouse',
#    'id': 10481,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10485: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.429485, 50.648194]},
#   'properties': {'class': 'place',
#    'place': 'Lympstone',
#    'name': 'Lympstone',
#    'id': 10485,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10499: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.11667, 51.5]},
#   'properties': {'class': 'place',
#    'place': 'England, port unspecified',
#    'name': 'England, port unspecified',
#    'id': 10499,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10501: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Airth',
#    'name': 'Airth',
#    'id': 10501,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10500: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'region',
#    'region': 'Scotland',
#    'name': 'Scotland',
#    'id': 10500,
#    'region__show_on_map': False,
#    'region__show_on_main_map': True}},
#  10502: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Borrowstounness',
#    'name': 'Borrowstounness',
#    'id': 10502,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10503: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Dundee',
#    'name': 'Dundee',
#    'id': 10503,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10504: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.25, 55.83333]},
#   'properties': {'class': 'place',
#    'place': 'Glasgow',
#    'name': 'Glasgow',
#    'id': 10504,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10505: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.75, 55.93333]},
#   'properties': {'class': 'place',
#    'place': 'Greenock',
#    'name': 'Greenock',
#    'id': 10505,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10506: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.16667, 55.95]},
#   'properties': {'class': 'place',
#    'place': 'Leith',
#    'name': 'Leith',
#    'id': 10506,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10507: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Lough Neagh',
#    'name': 'Lough Neagh',
#    'id': 10507,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10508: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.45, 56.7]},
#   'properties': {'class': 'place',
#    'place': 'Montrose',
#    'name': 'Montrose',
#    'id': 10508,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10509: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Ross',
#    'name': 'Ross',
#    'id': 10509,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10510: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Saltcoats',
#    'name': 'Saltcoats',
#    'id': 10510,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10511: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Largo, Fifeshire',
#    'name': 'Largo, Fifeshire',
#    'id': 10511,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10512: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.6051198, 55.070859]},
#   'properties': {'class': 'place',
#    'place': 'Dumfries',
#    'name': 'Dumfries',
#    'id': 10512,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10513: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Point Askaig',
#    'name': 'Point Askaig',
#    'id': 10513,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10514: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.605374, 55.424117]},
#   'properties': {'class': 'place',
#    'place': 'Cambletown',
#    'name': 'Cambletown',
#    'id': 10514,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10515: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.116057, 54.84279]},
#   'properties': {'class': 'place',
#    'place': 'Portpatrick',
#    'name': 'Portpatrick',
#    'id': 10515,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10516: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0001235, 0.0001235]},
#   'properties': {'class': 'place',
#    'place': 'Erwin',
#    'name': 'Erwin',
#    'id': 10516,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10517: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.094278, 57.149717]},
#   'properties': {'class': 'place',
#    'place': 'Aberdeen',
#    'name': 'Aberdeen',
#    'id': 10517,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10518: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.024055, 54.903367]},
#   'properties': {'class': 'place',
#    'place': 'Stranraer',
#    'name': 'Stranraer',
#    'id': 10518,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10519: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.4710467, 56.415157]},
#   'properties': {'class': 'place',
#    'place': 'Oban',
#    'name': 'Oban',
#    'id': 10519,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10599: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.01, 56.78036]},
#   'properties': {'class': 'place',
#    'place': 'Scotland, port unspecified',
#    'name': 'Scotland, port unspecified',
#    'id': 10599,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10601: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.49583, 51.89861]},
#   'properties': {'class': 'place',
#    'place': 'Cork',
#    'name': 'Cork',
#    'id': 10601,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10600: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'region',
#    'region': 'Ireland',
#    'name': 'Ireland',
#    'id': 10600,
#    'region__show_on_map': False,
#    'region__show_on_main_map': True}},
#  10602: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-7.55028, 52.57444]},
#   'properties': {'class': 'place',
#    'place': 'Dublin',
#    'name': 'Dublin',
#    'id': 10602,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10603: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Dungarvan',
#    'name': 'Dungarvan',
#    'id': 10603,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10604: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-9.04889, 53.27194]},
#   'properties': {'class': 'place',
#    'place': 'Galway',
#    'name': 'Galway',
#    'id': 10604,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10605: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.52331, 51.70644]},
#   'properties': {'class': 'place',
#    'place': 'Kinsale',
#    'name': 'Kinsale',
#    'id': 10605,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10606: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-8.66652, 52.66222]},
#   'properties': {'class': 'place',
#    'place': 'Limerick',
#    'name': 'Limerick',
#    'id': 10606,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10607: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Londonderry',
#    'name': 'Londonderry',
#    'id': 10607,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10608: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-7.59139, 54.79472]},
#   'properties': {'class': 'place',
#    'place': 'Ringsend',
#    'name': 'Ringsend',
#    'id': 10608,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10609: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Strangford',
#    'name': 'Strangford',
#    'id': 10609,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10610: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-7.11, 52.25833]},
#   'properties': {'class': 'place',
#    'place': 'Waterford',
#    'name': 'Waterford',
#    'id': 10610,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10611: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Wexford',
#    'name': 'Wexford',
#    'id': 10611,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10612: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.930119, 54.597285]},
#   'properties': {'class': 'place',
#    'place': 'Belfast',
#    'name': 'Belfast',
#    'id': 10612,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10613: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-5.9301199, 54.597285]},
#   'properties': {'class': 'place',
#    'place': 'Coleraine',
#    'name': 'Coleraine',
#    'id': 10613,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10699: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Ireland, port unspecified',
#    'name': 'Ireland, port unspecified',
#    'id': 10699,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10702: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.48333, 43.48333]},
#   'properties': {'class': 'place',
#    'place': 'Bayonne',
#    'name': 'Bayonne',
#    'id': 10702,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10700: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.70685, 45.745724]},
#   'properties': {'class': 'region',
#    'region': 'France',
#    'name': 'France',
#    'id': 10700,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  10703: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.56667, 44.83333]},
#   'properties': {'class': 'place',
#    'place': 'Bordeaux',
#    'name': 'Bordeaux',
#    'id': 10703,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10704: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.48333, 48.4]},
#   'properties': {'class': 'place',
#    'place': 'Brest',
#    'name': 'Brest',
#    'id': 10704,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10705: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Calais',
#    'name': 'Calais',
#    'id': 10705,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10706: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.63932, 47.7442]},
#   'properties': {'class': 'place',
#    'place': 'Camaret',
#    'name': 'Camaret',
#    'id': 10706,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10707: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [1.08333, 49.93333]},
#   'properties': {'class': 'place',
#    'place': 'Dieppe',
#    'name': 'Dieppe',
#    'id': 10707,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10708: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.0632, 48.63055]},
#   'properties': {'class': 'place',
#    'place': 'Dinard',
#    'name': 'Dinard',
#    'id': 10708,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10709: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [2.36667, 51.05]},
#   'properties': {'class': 'place',
#    'place': 'Dunkerque',
#    'name': 'Dunkerque',
#    'id': 10709,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10710: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.23333, 49.41667]},
#   'properties': {'class': 'place',
#    'place': 'Honfleur',
#    'name': 'Honfleur',
#    'id': 10710,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10711: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-4.01737, 48.74546]},
#   'properties': {'class': 'place',
#    'place': 'Ile de Batz',
#    'name': 'Ile de Batz',
#    'id': 10711,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10712: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.15, 46.16667]},
#   'properties': {'class': 'place',
#    'place': 'La Rochelle',
#    'name': 'La Rochelle',
#    'id': 10712,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10713: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.13333, 49.5]},
#   'properties': {'class': 'place',
#    'place': 'Le Havre',
#    'name': 'Le Havre',
#    'id': 10713,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10714: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.98232, 47.06284]},
#   'properties': {'class': 'place',
#    'place': 'Les Sables',
#    'name': 'Les Sables',
#    'id': 10714,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10715: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.36667, 47.75]},
#   'properties': {'class': 'place',
#    'place': 'Lorient',
#    'name': 'Lorient',
#    'id': 10715,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10716: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.4, 43.3]},
#   'properties': {'class': 'place',
#    'place': 'Marseille',
#    'name': 'Marseille',
#    'id': 10716,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10717: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.4, 43.3]},
#   'properties': {'class': 'place',
#    'place': 'Mediterranean coast (France)',
#    'name': 'Mediterranean coast (France)',
#    'id': 10717,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10718: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.16667, 47.26667]},
#   'properties': {'class': 'place',
#    'place': 'Mindin',
#    'name': 'Mindin',
#    'id': 10718,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10719: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.83333, 48.58333]},
#   'properties': {'class': 'place',
#    'place': 'Morlaix',
#    'name': 'Morlaix',
#    'id': 10719,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10720: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.55, 47.21667]},
#   'properties': {'class': 'place',
#    'place': 'Nantes',
#    'name': 'Nantes',
#    'id': 10720,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10721: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.03333, 47.28333]},
#   'properties': {'class': 'place',
#    'place': 'Paimboeuf',
#    'name': 'Paimboeuf',
#    'id': 10721,
#    'show_on_main_map': True,
#    'show_on_voyage_map': False}},
#  10722: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-3.35587, 47.70838]},
#   'properties': {'class': 'place',
#    'place': 'Port Louis',
#    'name': 'Port Louis',
#    'id': 10722,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10723: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Quimper',
#    'name': 'Quimper',
#    'id': 10723,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10724: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-0.98333, 45.93333]},
#   'properties': {'class': 'place',
#    'place': 'Rochefort',
#    'name': 'Rochefort',
#    'id': 10724,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10725: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.78, 48.51667]},
#   'properties': {'class': 'place',
#    'place': 'Saint-Brieuc',
#    'name': 'Saint-Brieuc',
#    'id': 10725,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10726: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.01667, 48.65]},
#   'properties': {'class': 'place',
#    'place': 'Saint-Malo',
#    'name': 'Saint-Malo',
#    'id': 10726,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10727: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.21361, 47.27432]},
#   'properties': {'class': 'place',
#    'place': 'Saint-Nazaire',
#    'name': 'Saint-Nazaire',
#    'id': 10727,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10728: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Saint-Tropez',
#    'name': 'Saint-Tropez',
#    'id': 10728,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10729: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [3.6966, 43.40176]},
#   'properties': {'class': 'place',
#    'place': 'Sète',
#    'name': 'Sète',
#    'id': 10729,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10730: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-2.75, 47.66667]},
#   'properties': {'class': 'place',
#    'place': 'Vannes',
#    'name': 'Vannes',
#    'id': 10730,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10799: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-1.55, 47.21667]},
#   'properties': {'class': 'place',
#    'place': 'France, port unspecified',
#    'name': 'France, port unspecified',
#    'id': 10799,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10810: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.91667, 52.35]},
#   'properties': {'class': 'place',
#    'place': 'Amsterdam',
#    'name': 'Amsterdam',
#    'id': 10810,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10800: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.96901, 53.006912]},
#   'properties': {'class': 'region',
#    'region': 'Netherlands',
#    'name': 'Netherlands',
#    'id': 10800,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  10821: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.28, 52.71667]},
#   'properties': {'class': 'place',
#    'place': 'Enkhuizen',
#    'name': 'Enkhuizen',
#    'id': 10821,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10822: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Hoorn ',
#    'name': 'Hoorn ',
#    'id': 10822,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10827: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Zaandam',
#    'name': 'Zaandam',
#    'id': 10827,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  10828: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [5.27, 52.54562]},
#   'properties': {'class': 'place',
#    'place': 'Zuider Zee',
#    'name': 'Zuider Zee',
#    'id': 10828,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10829: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.81991, 53.14933]},
#   'properties': {'class': 'place',
#    'place': 'Texel',
#    'name': 'Texel',
#    'id': 10829,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10830: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.5, 51.91667]},
#   'properties': {'class': 'place',
#    'place': 'Rotterdam',
#    'name': 'Rotterdam',
#    'id': 10830,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10831: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.67, 51.8]},
#   'properties': {'class': 'place',
#    'place': 'Dordrecht',
#    'name': 'Dordrecht',
#    'id': 10831,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10832: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.5986, 51.7514]},
#   'properties': {'class': 'place',
#    'place': 'Maze',
#    'name': 'Maze',
#    'id': 10832,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10833: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.62737, 51.70202]},
#   'properties': {'class': 'place',
#    'place': 'Moerdijk',
#    'name': 'Moerdijk',
#    'id': 10833,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  10834: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [4.13333, 51.83333]},
#   'properties': {'class': 'place',
#    'place': 'Hellevoetsluis',
#    'name': 'Hellevoetsluis',
#    'id': 10834,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10840: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [3.77109, 51.49647]},
#   'properties': {'class': 'place',
#    'place': 'Zeeland',
#    'name': 'Zeeland',
#    'id': 10840,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  10850: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [3.61, 51.5]},
#   'properties': {'class': 'place',
#    'place': 'Middelburg',
#    'name': 'Middelburg',
#    'id': 10850,
#    'show_on_main_map': True,
# ...
#    'id': 36201,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36200: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-61.71667, 16.0]},
#   'properties': {'class': 'region',
#    'region': 'Guadaloupe',
#    'name': 'Guadaloupe',
#    'id': 36200,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  36202: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-61.51667, 16.23333]},
#   'properties': {'class': 'place',
#    'place': 'Pointe-à-Pitre',
#    'name': 'Pointe-à-Pitre',
#    'id': 36202,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36203: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-61.26667, 15.93333]},
#   'properties': {'class': 'place',
#    'place': 'Marie-Galante',
#    'name': 'Marie-Galante',
#    'id': 36203,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  36204: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-61.4669, 16.2732]},
#   'properties': {'class': 'place',
#    'place': 'Grande-Terre, port unspecified',
#    'name': 'Grande-Terre, port unspecified',
#    'id': 36204,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36299: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-61.71667, 16.0]},
#   'properties': {'class': 'place',
#    'place': 'Guadeloupe, port unspecified',
#    'name': 'Guadeloupe, port unspecified',
#    'id': 36299,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  36301: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-52.33333, 4.93333]},
#   'properties': {'class': 'place',
#    'place': 'Cayenne',
#    'name': 'Cayenne',
#    'id': 36301,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36300: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-53.612239, 5.861294]},
#   'properties': {'class': 'region',
#    'region': 'French Guiana',
#    'name': 'French Guiana',
#    'id': 36300,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  36302: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-51.8, 3.9]},
#   'properties': {'class': 'place',
#    'place': 'Oyapock',
#    'name': 'Oyapock',
#    'id': 36302,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  36399: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'French Guiana, port unspecified',
#    'name': 'French Guiana, port unspecified',
#    'id': 36399,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  36401: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.78667, 20.04634]},
#   'properties': {'class': 'place',
#    'place': 'Tortuga',
#    'name': 'Tortuga',
#    'id': 36401,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36402: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.5125, 18.76944]},
#   'properties': {'class': 'place',
#    'place': 'Arcahaie',
#    'name': 'Arcahaie',
#    'id': 36402,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  36403: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.204, 19.75]},
#   'properties': {'class': 'place',
#    'place': 'Cap Français',
#    'name': 'Cap Français',
#    'id': 36403,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36404: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-73.75, 18.2]},
#   'properties': {'class': 'place',
#    'place': 'Cayes (Les)',
#    'name': 'Cayes (Les)',
#    'id': 36404,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36405: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.36667, 19.06667]},
#   'properties': {'class': 'place',
#    'place': 'Cul-de-Sac',
#    'name': 'Cul-de-Sac',
#    'id': 36405,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36406: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-71.83972, 19.66778]},
#   'properties': {'class': 'place',
#    'place': 'Fort Dauphin',
#    'name': 'Fort Dauphin',
#    'id': 36406,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36407: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.53472, 18.23417]},
#   'properties': {'class': 'place',
#    'place': 'Jacmel',
#    'name': 'Jacmel',
#    'id': 36407,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36408: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-74.11667, 18.65]},
#   'properties': {'class': 'place',
#    'place': 'Jérémie',
#    'name': 'Jérémie',
#    'id': 36408,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36409: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.63389, 18.51083]},
#   'properties': {'class': 'place',
#    'place': 'Léogane',
#    'name': 'Léogane',
#    'id': 36409,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36410: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-73.38, 19.8]},
#   'properties': {'class': 'place',
#    'place': 'Môle Saint Nicolas',
#    'name': 'Môle Saint Nicolas',
#    'id': 36410,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  36411: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.86694, 18.43139]},
#   'properties': {'class': 'place',
#    'place': 'Petit-Goâve',
#    'name': 'Petit-Goâve',
#    'id': 36411,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36412: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.335, 18.53917]},
#   'properties': {'class': 'place',
#    'place': 'Port-au-Prince',
#    'name': 'Port-au-Prince',
#    'id': 36412,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36413: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.83087, 19.93276]},
#   'properties': {'class': 'place',
#    'place': 'Port-de-Paix',
#    'name': 'Port-de-Paix',
#    'id': 36413,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36414: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.7, 19.11667]},
#   'properties': {'class': 'place',
#    'place': 'Saint-Marc',
#    'name': 'Saint-Marc',
#    'id': 36414,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36415: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-73.6512, 18.0694]},
#   'properties': {'class': 'place',
#    'place': 'Île à Vache',
#    'name': 'Île à Vache',
#    'id': 36415,
#    'show_on_main_map': False,
#    'show_on_voyage_map': False}},
#  36416: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0001235, 0.0001235]},
#   'properties': {'class': 'place',
#    'place': 'Cap Tiberon',
#    'name': 'Cap Tiberon',
#    'id': 36416,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36420: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [72.680158, 19.45115]},
#   'properties': {'class': 'place',
#    'place': 'Gonaïve',
#    'name': 'Gonaïve',
#    'id': 36420,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36421: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Aribonite',
#    'name': 'Aribonite',
#    'id': 36421,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36422: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.4598, 19.2011]},
#   'properties': {'class': 'place',
#    'place': 'Morne Rouge',
#    'name': 'Morne Rouge',
#    'id': 36422,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36423: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.966667, 19.916667]},
#   'properties': {'class': 'place',
#    'place': 'le Mustic (Moustique)',
#    'name': 'le Mustic (Moustique)',
#    'id': 36423,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36424: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.42, 18.73]},
#   'properties': {'class': 'place',
#    'place': 'Boucassin',
#    'name': 'Boucassin',
#    'id': 36424,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36425: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.68213, 19.44974]},
#   'properties': {'class': 'place',
#    'place': "L'Estère",
#    'name': "L'Estère",
#    'id': 36425,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36426: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Mont. de Chanteloup',
#    'name': 'Mont. de Chanteloup',
#    'id': 36426,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36427: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.429513, 19.751717]},
#   'properties': {'class': 'place',
#    'place': 'Port-Margot',
#    'name': 'Port-Margot',
#    'id': 36427,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36428: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Chicahominy',
#    'name': 'Chicahominy',
#    'id': 36428,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36429: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.243781, 19.526965]},
#   'properties': {'class': 'place',
#    'place': 'Dondon',
#    'name': 'Dondon',
#    'id': 36429,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36430: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Longemalle (Habitation)',
#    'name': 'Longemalle (Habitation)',
#    'id': 36430,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36431: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.12528, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Limonade',
#    'name': 'Limonade',
#    'id': 36431,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36432: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-73.130535, 18.279928]},
#   'properties': {'class': 'place',
#    'place': 'Fond',
#    'name': 'Fond',
#    'id': 36432,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36433: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-71.729625, 19.547372]},
#   'properties': {'class': 'place',
#    'place': 'Ouanaminthe',
#    'name': 'Ouanaminthe',
#    'id': 36433,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36434: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-74.164365, 18.274651]},
#   'properties': {'class': 'place',
#    'place': 'Charbonniere',
#    'name': 'Charbonniere',
#    'id': 36434,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36435: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-73.0999996, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Nippes',
#    'name': 'Nippes',
#    'id': 36435,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36436: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.33333, 18.55]},
#   'properties': {'class': 'place',
#    'place': 'Belair',
#    'name': 'Belair',
#    'id': 36436,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36437: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Boucan-Champagne',
#    'name': 'Boucan-Champagne',
#    'id': 36437,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36438: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-73.15499, 19.63011]},
#   'properties': {'class': 'place',
#    'place': 'Petite Anse',
#    'name': 'Petite Anse',
#    'id': 36438,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36439: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.536086, 18.235518]},
#   'properties': {'class': 'place',
#    'place': 'Rue Bourbon',
#    'name': 'Rue Bourbon',
#    'id': 36439,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36440: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.7682, 18.4283]},
#   'properties': {'class': 'place',
#    'place': 'Grand Coâve',
#    'name': 'Grand Coâve',
#    'id': 36440,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36442: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 18.6257]},
#   'properties': {'class': 'place',
#    'place': 'Bon Repos',
#    'name': 'Bon Repos',
#    'id': 36442,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36443: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-73.04, 19.906]},
#   'properties': {'class': 'place',
#    'place': "Port à l'écu",
#    'name': "Port à l'écu",
#    'id': 36443,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36444: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [0.0, 0.0]},
#   'properties': {'class': 'place',
#    'place': 'Belair, rue de Vaudreuil',
#    'name': 'Belair, rue de Vaudreuil',
#    'id': 36444,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36446: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-79.93, 18.54]},
#   'properties': {'class': 'place',
#    'place': "Fond-d'Icaques",
#    'name': "Fond-d'Icaques",
#    'id': 36446,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  36499: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.20417, 19.75778]},
#   'properties': {'class': 'place',
#    'place': 'Saint-Domingue, port unspecified',
#    'name': 'Saint-Domingue, port unspecified',
#    'id': 36499,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  36599: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.20417, 19.75778]},
#   'properties': {'class': 'place',
#    'place': 'French Caribbean, colony unspecified',
#    'name': 'French Caribbean, colony unspecified',
#    'id': 36599,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  36500: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-72.20417, 19.75778]},
#   'properties': {'class': 'region',
#    'region': 'Other French Caribbean',
#    'name': 'Other French Caribbean',
#    'id': 36500,
#    'region__show_on_map': False,
#    'region__show_on_main_map': True}},
#  37010: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-64.82, 17.77305]},
#   'properties': {'class': 'place',
#    'place': 'St. Croix',
#    'name': 'St. Croix',
#    'id': 37010,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  37000: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-64.9, 18.0]},
#   'properties': {'class': 'region',
#    'region': 'Danish West Indies',
#    'name': 'Danish West Indies',
#    'id': 37000,
#    'region__show_on_map': True,
#    'region__show_on_main_map': True}},
#  37020: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-64.94, 18.34141]},
#   'properties': {'class': 'place',
#    'place': 'St. Thomas',
#    'name': 'St. Thomas',
#    'id': 37020,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  37030: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-64.7399494, 18.3274718]},
#   'properties': {'class': 'place',
#    'place': 'St. John (Virgin Islands)',
#    'name': 'St. John (Virgin Islands)',
#    'id': 37030,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  37040: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-64.430411, 18.449853]},
#   'properties': {'class': 'place',
#    'place': 'Spanish Town, British Virgin Islands',
#    'name': 'Spanish Town, British Virgin Islands',
#    'id': 37040,
#    'show_on_main_map': True,
#    'show_on_voyage_map': True}},
#  37099: {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-64.8, 18.02]},
#   'properties': {'class': 'place',
#    'place': 'Danish West Indies, colony unspecified',
#    'name': 'Danish West Indies, colony unspecified',
#    'id': 37099,
#    'show_on_main_map': False,
#    'show_on_voyage_map': True}},
#  ...}

# %%
"""
was able to implement date slider, get year labels as well. 
issues: 
different configurations of date vars did
"""

"""
ends with value field
"""

# voyage_dates__imp_arrival_at_port_of_dis_yyyy
"""
geo_vars: lat, lon, port of emb
"""

"""
choose port of emb or disemb, i pack on the suffix which gets the lat and lon and the place name
"""
"""
dates_vars: start, end
"""

"""
call to value->pass to second url->get value->lookup on geo_codes->mutate df->then create bubble map: THIS IS THE WORKFLOW
"""

"""
port of emb, port of disemb, region, broad_region of emb and disemb
"""



"""
options call to voyages endpoint
load it as a dictionary
options_dict = options_dict[options[0]]
"""
